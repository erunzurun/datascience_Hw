# %%
is_tested = True
print(type(is_tested))
# Out:
# <class 'bool'>

# %%
print("Yes" == 'Yes')

print(((2>1) == (5<10)))

c = '2'
d = 2
print(c == d)
# Out:
# True
# True
# False

# %%
print(True or True)
print(True or False)
print(False or False)
print(1 < 2 or 3 < 1)
print(3 < 1 or 1 > 6)
print(1 == 1 or 1 < 2)
# Out:
# True
# True
# False
# True
# False
# True

# %%
print(True or True)
print(True or False)
print(False or False)
print(1 == 1 and 1 < 2)
print(1 < 2 and 3 < 1)
# Out:
# True
# True
# False
# True
# False

# %%
puppy = "maltepoo"
age = 1
is_yes = False

if puppy == "maltese":
    is_yes = True
    print("말티즈 맞아요.")
    if age < 3:
        print("말티즈 새끼에요")
    
elif puppy == "poodle":
    is_yes = True
    print("푸들 맞아요.")
    if age < 3:
        print("푸들 새끼에요")
        
else:
    is_yes = True
    print("말티푸 맞아요")
    
    
print(is_yes)
# Out:
# 말티푸 맞아요
# True

# %%
"Exception Handling"

x = 1
try:
    print(y)
    print(x)
except:
    print("ERROR")

print("continue...")
# Out:
# ERROR
# continue...
