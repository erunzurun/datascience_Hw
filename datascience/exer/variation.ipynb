# %%
"""
printf() function
"""

print('"Hello world!"')
print(100)
pi = 3.14
print(pi)

intro = "My name is "
name = "Park Jeong Min"
print(intro + name)
# Out:
# "Hello world!"
# 100
# 3.14
# My name is Park Jeong Min

# %%
"""
Variables
"""

user_name = "Park Jeong Min"
user_phone_number = "01012345678"
user_address = "Suwon"
is_student = True

# 본인을 표현할 수 있는 세 가지 이상의 정보를 변수로 정의하시오.

# %%
"""
Data Types: Integers
"""

Chairs = 6
desks = 6
sofas = 1
broken_chairs = -1
partitions = 4

# 본인의 집에 있는 사물의 개수를 정수 유형의 변수로 전의하시오(세 가지 이상).

# %%
"""
Data Types Real Numbers
"""

PI = 3.14
kospi_index = 24.46
ur_percentage = 0.2
sr_percentage = 1.2

# 본인이 알고 있는 실수를 변수로 정의하시오(세 가지 이상).

# %%
"""
Data Types: Strings
"""

favorite_game = "BIOSHOCK"
facorite_movie_genre = "thriller"
favorite_music_genre = "pop"

#본인의 좋아하는 것들을 문자열 변수로 정의하시오.

# %%
"""
Plus-Equals Operations
"""
a = 8
a **= 2

message = "오 쉿 time's up "
message2 = "벌써 엄마 뱃속에서 나와 20"

final_message = message + message2

print(a)
print(final_message)
# Out:
# 64
# 오 쉿 time's up 벌써 엄마 뱃속에서 나와 20

# %%
"""
Errors
"""
    
#Name Errors

print(my_school)
my_school = "HSU"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cf7375f36bf8> in <module>
#       5 #Name Errors
#       6
# ----> 7 print(my_school)
#       8 my_school = "HSU"
#
# NameError: name 'my_school' is not defined
